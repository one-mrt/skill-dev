# %% [markdown]
# <h1>10.12 Графики табличного типа</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('./data/tips.csv',header=0)
sns.set()

# %%
correlation = df.corr()

sns.heatmap(correlation,annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>
