# %% [markdown]
# <h1>1.13 Тренировка</h1>
# <h2>Задание 1.13.1</h2>

# %%
import pandas as pd

data = pd.DataFrame({
    'value' : [48, 44, 42.5, 40.5, 40.5, 39, 39, 38, 38, 38, 35, 33, 30.2, 30, 26, 19.3, 27, 21]
})

boxplot = data.boxplot()
data.value.median()
# Out:
# 38.0

# %% [markdown]
# <h2>Задание 1.13.2</h2>

# %%
df = pd.DataFrame({
    'group_a': [72, 66, 63.75, 60.75, 60.75, 58.5, 58.5, 57, 57, 57, 52.5, 49.5, 45.3, 45, 39, 28.95, 40.5, 31.5, 49],
    'group_b': [71, 72, 60, 50, 57, 77, 81, 58, 62, 61, 73, 74, 76, 65, 66, 67, 67, 67, 69]
})

boxGraph = df.boxplot()

# %%
df = pd.DataFrame({
    'X' : [38,39,40,41,42,43],
    'P' : [0.1,0.1,0.3,0.2,0.2,0.1]
})

df1 = pd.DataFrame({
    'X' : [400,410,420,430,440,450],
    'P' : [0.1,0.1,0.3,0.2,0.2,0.1]
})

#df1.X.var()
df.X.std()
# Out:
# 1.8708286933869707
